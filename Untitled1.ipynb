# %%
import numpy as np
import pandas as pd
import torch
import math
from tensorflow.keras.preprocessing.sequence import pad_sequences
import tensorboardX as tbx

from src.models import BiLM, SoftmaxLoss
from src.preprocessing import Tokenizer

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## BiLM test

# %%
sent = torch.tensor([[1, 3, 4, 5, 2, 0]
                       , [1, 4, 3, 6, 4, 2]])

# %%
inputs = sent.transpose(1, 0).view(-1, 2)

# %%
sent.shape
# Out:
# torch.Size([2, 6])

# %%
inputs.shape
# Out:
# torch.Size([6, 2])

# %%
bi_lm_model = BiLM(100, 10, 7)

loss_func = SoftmaxLoss()

forward_output, backword_output, c = bi_lm_model(inputs)

loss = loss_func(forward_output, backword_output, sent)

optimizer = torch.optim.SGD(bi_lm_model.parameters(), lr=0.01, momentum=0.9)

# %%
for epoch in range(10):
    epoch_loss = 0.0
    for batch in range(10):
        #inputs, target = batch
        
        optimizer.zero_grad()
        
        forward_output, backword_output, c = bi_lm_model(inputs)
        loss = loss_func(forward_output, backword_output, sent)
        loss.backward()
        optimizer.step()
        
        epoch_loss += loss.data
# Out:
# tensor(2.8676)
# tensor(2.8327)
# tensor(2.7853)
# tensor(2.7352)
# tensor(2.6856)
# tensor(2.6375)
# tensor(2.5910)
# tensor(2.5462)
# tensor(2.5031)
# tensor(2.4617)

# %%
c[0, :, :], c[1, :, :]
# Out:
# (tensor([[ 0.1117, -0.0517, -0.1969,  0.2721, -0.1754,  0.4400, -0.3322,  0.1445,
#           -0.0375,  0.5117],
#          [ 0.7798,  0.2518, -0.4081,  0.4856, -0.0018,  0.7685,  0.0832,  0.0889,
#           -0.4110,  1.3958]], grad_fn=<SliceBackward>),
#  tensor([[-1.3118, -0.1223,  0.1932, -0.8429,  0.0526, -0.4303, -0.2412,  0.4959,
#           -0.3689,  0.3246],
#          [-1.8531, -0.0904,  0.0867, -0.9414, -0.1572, -0.5205, -0.3179,  0.4663,
#           -0.6213,  0.2895]], grad_fn=<SliceBackward>))

# %% [markdown]
# ## Preprocessing test

# %%
sentences = [
    ['All', 'work', 'and', 'no', 'play'],
    ['makes', 'Jack', 'a', 'dull', 'boy', '.'],
    ['MAKE', 'AMERICA', 'GREAT', 'AGAIN'],
    ['Poyoi']
]

# %%
wiki_df = pd.read_pickle("data/all_wiki_sentence_split_words_using_compound_dict.pkl")
wiki_df.head()
# Out:
#        _id      title                                           sentence  \
# 0  1300364  イソチオシアネート  イソチオシアネート（Isothiocyanate）とは、-N=C=Sという構造を持つ物質の総...
# 1  1300364  イソチオシアネート  アブラナ科の植物にしばしば含まれるアリルイソチオシアネートはカラシ油に含まれ、辛味の原因とな...
# 2  1300364  イソチオシアネート                          エドマン分解ではアミノ酸の配列の解析に用いられる。
# 3  1300364  イソチオシアネート                イソチオシアネートは常に炭素原子を求電子中心とする求電子剤として働く。
# 4  1300364  イソチオシアネート  フェニチルイソチオシアネートやスルフォラファンなどのイソチオシアネートは発癌や腫瘍化を防ぎ、...
#
#                                                words  \
# 0  [イソチオシアネート, （, Isothiocyanate, ）, と, は, 、, -, ...
# 1  [アブラナ, 科, の, 植物, に, しばしば, 含ま, れる, アリルイソチオシアネート...
# 2  [エド, マン, 分解, で, は, アミノ酸, の, 配列, の, 解析, に, 用い, ...
# 3  [イソチオシアネート, は, 常に, 炭素, 原子, を, 求, 電子, 中心, と, する...
# 4  [フェニチルイソチオシアネート, や, スルフォラファン, など, の, イソチオシアネート...
#
#                                           repl_words
# 0  [[title-compound], （, Isothiocyanate, ）, と, は,...
# 1  [アブラナ, 科, の, 植物, に, しばしば, 含ま, れる, [compound], ...
# 2  [エド, マン, 分解, で, は, アミノ酸, の, 配列, の, 解析, に, 用い, ...
# 3  [[title-compound], は, 常に, 炭素, 原子, を, 求, 電子, 中心...
# 4  [フェニチルイソチオシアネート, や, [compound], など, の, [title-...

# %%
def attach_BOS_EOS(sentences):
    _sents = sentences.copy()
    for s in _sents:
        s.insert(0, '<BOS>')
        s.append('<EOS>')
    
    return _sents

# %%
sentences = wiki_df.repl_words.tolist()

tokenizer = Tokenizer()
tokenizer.fit_word(sentences)
sentences = attach_BOS_EOS(sentences)
sentences = tokenizer.transform_word(sentences)

# %%
def batch_generator(data, batch_size):
    data_size = len(data)
    num_batches = math.ceil(data_size / batch_size)
    
    shuffle_indices = np.random.permutation(np.arange(data_size))
    shuffle_data = np.array(data)[shuffle_indices]
    for batch_num in range(num_batches):
        start_index = batch_num * batch_size
        end_index = min((batch_num + 1) * batch_size, data_size)
        batch_data = shuffle_data[start_index:end_index]
        batch_data = pad_sequences(batch_data, padding='post')
        
        batch_data = torch.tensor(batch_data).long()
        batch_X = batch_data.transpose(1, 0).view(-1, batch_data.shape[0])
        
        yield (batch_num + 1), batch_X, batch_data

# %%
bi_lm_model = BiLM(100, 100, len(tokenizer.vocab_word))
loss_func = SoftmaxLoss()
optimizer = torch.optim.Adam(bi_lm_model.parameters())

# %%
writer = tbx.SummaryWriter()

batch_size = 32
num_batches = math.ceil(len(sentences) / batch_size)

for epoch in range(1):
    epoch_loss = 0.0
    for i, data, target in batch_generator(sentences, batch_size):
        optimizer.zero_grad()
        forward_output, backword_output, c = bi_lm_model(data)
        loss = loss_func(forward_output, backword_output, target)
        loss.backward()
        optimizer.step()
        
        writer.add_scalar('loss', loss.data, global_step=(epoch * batch_size + i))
        epoch_loss += loss.data
    
    print(epoch_loss / num_batches)
    
writer.close()
# Out:
# tensor(0.0076)

# %%
bi_lm_model

# %%
target[target > 2]
# Out:
# tensor([1362, 2150,   74,   75,  977,    9, 1204, 2114,   23,  127,   91,   10,
#          367,  368,   21, 2180, 2421,   91, 1570,   20,   18, 6551,   30,   31,
#           91,  373,  119,   45,   49,   50,   35])

# %%
torch.exp(backword_output).argmax(-1)
# Out:
# tensor([21, 10, 10, 10, 10, 10, 21, 21, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10,
#         10, 21, 10, 10, 10, 10, 10, 10, 21, 10, 10, 35, 35])

# %%
tokenizer.vocab_word
# Out:
# {'<PAD>': 0,
#  '<BOS>': 1,
#  '<EOS>': 2,
#  '<UNK>': 3,
#  '[title-compound]': 4,
#  '（': 5,
#  'Isothiocyanate': 6,
#  '）': 7,
#  'と': 8,
#  'は': 9,
#  '、': 10,
#  '-': 11,
#  'N': 12,
#  '=': 13,
#  'C': 14,
#  'S': 15,
#  'という': 16,
#  '構造': 17,
#  'を': 18,
#  '持つ': 19,
#  '物質': 20,
#  'の': 21,
#  '総称': 22,
#  'で': 23,
#  'あり': 24,
#  '[compound]': 25,
#  '酸素': 26,
#  '原子': 27,
#  '硫黄': 28,
#  '置換': 29,
#  'する': 30,
#  'こと': 31,
#  'によって': 32,
#  '得': 33,
#  'られる': 34,
#  '。': 35,
#  'アブラナ': 36,
#  '科': 37,
#  '植物': 38,
#  'に': 39,
#  'しばしば': 40,
#  '含ま': 41,
#  'れる': 42,
#  'カラシ': 43,
#  '油': 44,
#  'れ': 45,
#  '辛味': 46,
#  '原因': 47,
#  'なっ': 48,
#  'て': 49,
#  'いる': 50,
#  'エド': 51,
#  'マン': 52,
#  '分解': 53,
#  'アミノ酸': 54,
#  '配列': 55,
#  '解析': 56,
#  '用い': 57,
#  '常に': 58,
#  '炭素': 59,
#  '求': 60,
#  '電子': 61,
#  '中心': 62,
#  '剤': 63,
#  'として': 64,
#  '働く': 65,
#  'フェニチルイソチオシアネート': 66,
#  'や': 67,
#  'など': 68,
#  '発癌': 69,
#  '腫瘍': 70,
#  '化': 71,
#  '防ぎ': 72,
#  '化学': 73,
#  '的': 74,
#  'な': 75,
#  '抗': 76,
#  'がん': 77,
#  'なる': 78,
#  'これら': 79,
#  '様々': 80,
#  'レベル': 81,
#  '働き': 82,
#  '特に': 83,
#  'シトクローム': 84,
#  'P': 85,
#  '450': 86,
#  '阻害': 87,
#  'し': 88,
#  '防ぐ': 89,
#  '作用': 90,
#  'が': 91,
#  '知ら': 92,
#  'また': 93,
#  '細胞': 94,
#  'アポトーシス': 95,
#  '起こさ': 96,
#  'せる': 97,
#  '示さ': 98,
#  '例えば': 99,
#  'タンパク質': 100,
#  'BCl': 101,
#  '2': 102,
#  '生産': 103,
#  '薬剤': 104,
#  '抵抗': 105,
#  '性': 106,
#  '白血病': 107,
#  'も': 108,
#  '成功': 109,
#  '(': 110,
#  'halon': 111,
#  ')': 112,
#  '炭化': 113,
#  '水素': 114,
#  '一部': 115,
#  'または': 116,
#  '全て': 117,
#  'ハロゲン': 118,
#  'さ': 119,
#  'た': 120,
#  'ハロ': 121,
#  'カーボン': 122,
#  'うち': 123,
#  '臭素': 124,
#  '含む': 125,
#  'もの': 126,
#  'ある': 127,
#  'halogenated': 128,
#  'hydrocarbon': 129,
#  '語源': 130,
#  'アメリカ': 131,
#  '陸軍': 132,
#  '工兵': 133,
#  '司令': 134,
#  '部': 135,
#  'USACE': 136,
#  '1948': 137,
#  '年': 138,
#  '命名': 139,
#  '類': 140,
#  'halons': 141,
#  ')、': 142,
#  '化合': 143,
#  '物': 144,
#  'compounds': 145,
#  'いう': 146,
#  'ン': 147,
#  'に対し': 148,
#  'ず': 149,
#  'フッ素': 150,
#  '塩素': 151,
#  'のみ': 152,
#  'フロン': 153,
#  'クロロフルオロカーボン': 154,
#  '呼ぶ': 155,
#  '含める': 156,
#  'ただし': 157,
#  '日本': 158,
#  '特有': 159,
#  '語': 160,
#  '国際': 161,
#  '通用': 162,
#  '名': 163,
#  '法': 164,
#  '定め': 165,
#  '「': 166,
#  '」': 167,
#  'あと': 168,
#  '～': 169,
#  '5': 170,
#  '桁': 171,
#  '数字': 172,
#  '続ける': 173,
#  '数': 174,
#  'ヨウ': 175,
#  '素': 176,
#  '最後': 177,
#  '0': 178,
#  '連続': 179,
#  '場合': 180,
#  '省略': 181,
#  'したがって': 182,
#  '通常': 183,
#  'あれ': 184,
#  'ば': 185,
#  '4': 186,
#  'なり': 187,
#  '3': 188,
#  '表さ': 189,
#  'この': 190,
#  '一般': 191,
#  '異なる': 192,
#  '明示': 193,
#  'H': 194,
#  'C×': 195,
#  '+': 196,
#  '－': 197,
#  'F': 198,
#  'Cr': 199,
#  'I': 200,
#  '計算': 201,
#  '異性': 202,
#  '体': 203,
#  '区別': 204,
#  'でき': 205,
#  'ない': 206,
#  '慣習': 207,
#  '1': 208,
#  'つ': 209,
#  '表す': 210,
#  '例外': 211,
#  '11': 212,
#  'どおり': 213,
#  'なら': 214,
#  '113': 215,
#  '2600': 216,
#  '26': 217,
#  '慣用': 218,
#  '一覧': 219,
#  '以外': 220,
#  '可能': 221,
#  '多い': 222,
#  '実際': 223,
#  '呼ば': 224,
#  '希': 225,
#  '目': 226,
#  '厳密': 227,
#  '意味': 228,
#  '・': 229,
#  '1301': 230,
#  'モントリオール': 231,
#  '議定': 232,
#  '書': 233,
#  'オゾン': 234,
#  '層': 235,
#  '破壊': 236,
#  '特定': 237,
#  '指定': 238,
#  'おり': 239,
#  '1994': 240,
#  '月': 241,
#  '日': 242,
#  'から': 243,
#  '第': 244,
#  '条': 245,
#  '非': 246,
#  '適用': 247,
#  '国': 248,
#  '先進': 249,
#  '製造': 250,
#  '等': 251,
#  '全廃': 252,
#  '消火': 253,
#  '設備': 254,
#  '使わ': 255,
#  'これ': 256,
#  '遮断': 257,
#  '効果': 258,
#  '加え': 259,
#  '熱': 260,
#  '生じ': 261,
#  '燃焼': 262,
#  'により': 263,
#  '発生': 264,
#  '高': 265,
#  '活性': 266,
#  '水酸基': 267,
#  '取り除く': 268,
#  '触媒': 269,
#  'X': 270,
#  '→': 271,
#  'HX': 272,
#  'OH': 273,
#  '利用': 274,
#  '1950': 275,
#  '1960': 276,
#  'ごろ': 277,
#  '商品': 278,
#  'もともと': 279,
#  '航空機': 280,
#  '搭載': 281,
#  '用': 282,
#  '開発': 283,
#  '液体': 284,
#  '燃料': 285,
#  '火災': 286,
#  '主': 287,
#  'しかし': 288,
#  '1993': 289,
#  '末': 290,
#  '全': 291,
#  '世界': 292,
#  '2009': 293,
#  '廃止': 294,
#  'その': 295,
#  'ため': 296,
#  '現在': 297,
#  'リサイクルハロン': 298,
#  '航空': 299,
#  '軍事': 300,
#  '採掘': 301,
#  '穀物': 302,
#  'サイロ': 303,
#  '製紙': 304,
#  '工場': 305,
#  '特殊': 306,
#  '分野': 307,
#  '主体': 308,
#  '消防': 309,
#  'いずれ': 310,
#  '認め': 311,
#  'られ': 312,
#  '2001': 313,
#  '追加': 314,
#  'ラウ': 315,
#  'レス': 316,
#  'りゅう': 317,
#  'さん': 318,
#  'ナトリウム': 319,
#  ',': 320,
#  '陰': 321,
#  'イオン': 322,
#  '界面': 323,
#  '用途': 324,
#  'シャンプー': 325,
#  '歯磨き': 326,
#  '起': 327,
#  '泡': 328,
#  '業務': 329,
#  '洗剤': 330,
#  '脱脂': 331,
#  '多岐': 332,
#  'わたる': 333,
#  'n': 334,
#  '表記': 335,
#  'OCH': 336,
#  'CH': 337,
#  'LD': 338,
#  '50': 339,
#  '1995': 340,
#  'mg': 341,
#  '/': 342,
#  'kg': 343,
#  'ラット': 344,
#  '：': 345,
#  '経口': 346,
#  'エトキシ': 347,
#  'w': 348,
#  ':': 349,
#  'Ethoxylation': 350,
#  '後': 351,
#  '中和': 352,
#  '合成': 353,
#  '12': 354,
#  '25': 355,
#  'nC': 356,
#  'O': 357,
#  '⟶': 358,
#  'OC': 359,
#  'nOH': 360,
#  'nOSO': 361,
#  'Na': 362,
#  '加える': 363,
#  '方法': 364,
#  '過程': 365,
#  '事実': 366,
#  'いくつ': 367,
#  'か': 368,
#  '製品': 369,
#  '低': 370,
#  '濃度': 371,
#  '含ん': 372,
#  '確認': 373,
#  '式': 374,
#  '有機': 375,
#  '以下': 376,
#  '示す': 377,
#  '種': 378,
#  '存在': 379,
#  'benzyl': 380,
#  '成長': 381,
#  '刺激': 382,
#  '一': 383,
#  '世代': 384,
#  'サイトカイニン': 385,
#  '花': 386,
#  '咲かせ': 387,
#  '分裂': 388,
#  '促進': 389,
#  '果実': 390,
#  '豊富': 391,
#  '呼吸': 392,
#  'キナーゼ': 393,
#  '抑制': 394,
#  'ポストハーベスト': 395,
#  '農薬': 396,
#  '使用': 397,
#  'できる': 398,
#  '生理学': 399,
#  '者': 400,
#  'フォルク・スクーグ': 401,
#  '初めて': 402,
#  '実験': 403,
#  '英': 404,
#  'Rosin': 405,
#  'マツ': 406,
#  '樹液': 407,
#  '松脂': 408,
#  'まつ': 409,
#  'バルサム': 410,
#  '集め': 411,
#  'テレピン': 412,
#  '精油': 413,
#  '蒸留': 414,
#  '残る': 415,
#  '残留': 416,
#  '酸': 417,
#  'パ': 418,
#  'ラスト': 419,
#  'イソピマール': 420,
#  '主成分': 421,
#  '天然': 422,
#  '樹脂': 423,
#  'コロホニー': 424,
#  'あるいは': 425,
#  'コロホニウム': 426,
#  '英語': 427,
#  'Colophony': 428,
#  'グリーク・ピッチ': 429,
#  '関連': 430,
#  '品': 431,
#  '旧時': 432,
#  '海軍': 433,
#  '甲板': 434,
#  '防水': 435,
#  '滑り': 436,
#  '止め': 437,
#  'よく': 438,
#  'Naval': 439,
#  'stores': 440,
#  'ネーバル・ストアーズ': 441,
#  '中国': 442,
#  '松': 443,
#  '香': 444,
#  'ソンシアン': 445,
#  'sōngxiāng': 446,
#  '日本語': 447,
#  '常温': 448,
#  '黄色': 449,
#  '褐色': 450,
#  '透明': 451,
#  'ガラス': 452,
#  '様': 453,
#  '固体': 454,
#  '生': 455,
#  '揮発': 456,
#  '成分': 457,
#  '蒸発': 458,
#  'しまう': 459,
#  '固まっ': 460,
#  'ロ': 461,
#  'ジン': 462,
#  'ピッチ': 463,
#  '分': 464,
#  'ので': 465,
#  '近代': 466,
#  '精製': 467,
#  '粉末': 468,
#  '加工': 469,
#  '淡': 470,
#  '受け': 471,
#  '容易': 472,
#  '固': 473,
#  '結': 474,
#  '純度': 475,
#  '原料': 476,
#  '樹': 477,
#  '製法': 478,
#  '性状': 479,
#  '75': 480,
#  '℃': 481,
#  '前後': 482,
#  '軟化': 483,
#  '約': 484,
#  '100': 485,
#  '超える': 486,
#  '貿易': 487,
#  '熱い': 488,
#  '液状': 489,
#  '鉄': 490,
#  'ドラム': 491,
#  '詰め': 492,
#  '冷え': 493,
#  '状態': 494,
#  '輸出': 495,
#  '可燃': 496,
#  '黒': 497,
#  '煙': 498,
#  '出し': 499,
#  'ながら': 500,
#  '燃える': 501,
#  '火': 502,
#  'くべる': 503,
#  '燃え': 504,
#  'やすく': 505,
#  '時代': 506,
#  '劇': 507,
#  '火薬': 508,
#  '使い方': 509,
#  'シーン': 510,
#  '登場': 511,
#  'アルコール': 512,
#  '可': 513,
#  '溶': 514,
#  '水': 515,
#  '不溶': 516,
#  '産地': 517,
#  '中華人民共和国': 518,
#  '広西': 519,
#  'チワン': 520,
#  '族': 521,
#  '自治': 522,
#  '区': 523,
#  '広東': 524,
#  '省': 525,
#  '福建': 526,
#  '雲南': 527,
#  '江西': 528,
#  'ベトナム': 529,
#  'インドネシア': 530,
#  'アメリカ合衆国': 531,
#  'ニュージーランド': 532,
#  'ブラジル': 533,
#  'インド': 534,
#  '年産': 535,
#  '60': 536,
#  '万': 537,
#  'トン': 538,
#  '松やに': 539,
#  '採取': 540,
#  '異なり': 541,
#  'スラッシュ': 542,
#  'バビショウ': 543,
#  'タイワンアカマツ': 544,
#  'ウンナン': 545,
#  'ケシアマツ': 546,
#  '移入': 547,
#  'について': 548,
#  '地域': 549,
#  '違い': 550,
#  'クラフト': 551,
#  'パルプ': 552,
#  '作る': 553,
#  'とき': 554,
#  '副': 555,
#  '粗': 556,
#  'トール': 557,
#  'トールロジン': 558,
#  'アジア': 559,
#  '直接': 560,
#  '立木': 561,
#  '分離': 562,
#  '得る': 563,
#  'ガムロジン': 564,
#  '他': 565,
#  '伐採': 566,
#  '松の木': 567,
#  '根': 568,
#  '抽出': 569,
#  '集める': 570,
#  'ウッド': 571,
#  'Wood': 572,
#  '天産': 573,
#  '天候': 574,
#  '需要': 575,
#  '要因': 576,
#  '価格': 577,
#  '大きく': 578,
#  '変動': 579,
#  'より': 580,
#  '不足': 581,
#  '旺盛': 582,
#  '高騰': 583,
#  '続け': 584,
#  '1000': 585,
#  'ドル': 586,
#  '程度': 587,
#  'あっ': 588,
#  '2010': 589,
#  '2000': 590,
#  '突破': 591,
#  '3000': 592,
#  '2011': 593,
#  '入っ': 594,
#  '高値': 595,
#  '更新': 596,
#  '3400': 597,
#  '強': 598,
#  '最': 599,
#  'つける': 600,
#  'つづい': 601,
#  '急落': 602,
#  'いったん': 603,
#  '切っ': 604,
#  '2013': 605,
#  '9': 606,
#  '以降': 607,
#  '推移': 608,
#  'まま': 609,
#  '野球': 610,
#  'ロジンバッグ': 611,
#  'ダンス': 612,
#  '会場': 613,
#  '床': 614,
#  '面': 615,
#  'へ': 616,
#  '散布': 617,
#  'バイオリン': 618,
#  '胡弓': 619,
#  '弦楽器': 620,
#  '弓': 621,
#  '線': 622,
#  '琴線': 623,
#  '塗布': 624,
#  'はんだ': 625,
#  'フラックス': 626,
#  'レンズ': 627,
#  '研磨': 628,
#  '器具': 629,
#  '香料': 630,
#  '粘着': 631,
#  'はえ': 632,
#  '取り': 633,
#  '紙': 634,
#  '薬局方': 635,
#  '収載': 636,
#  'プラスター': 637,
#  '貼り': 638,
#  '薬': 639,
#  '外用': 640,
#  '昔': 641,
#  '手紙': 642,
#  '封印': 643,
#  'ビール瓶': 644,
#  '作ら': 645,
#  '簡単': 646,
#  '割れ': 647,
#  '人': 648,
#  '殴っ': 649,
#  '怪我': 650,
#  '粉々': 651,
#  '点': 652,
#  '本物': 653,
#  '着火': 654,
#  'アヒル': 655,
#  '家禽': 656,
#  '羽根': 657,
#  '根本': 658,
#  'きれい': 659,
#  '抜く': 660,
#  'のに': 661,
#  'あらかた': 662,
#  '毛抜き': 663,
#  '熱し': 664,
#  '漬け': 665,
#  'ところ': 666,
#  'はがす': 667,
#  '行わ': 668,
#  'い': 669,
#  '禁止': 670,
#  '反応': 671,
#  'せ': 672,
#  'サイズ': 673,
#  '印刷': 674,
#  'インキ': 675,
#  '塗料': 676,
#  '接着': 677,
#  '部品': 678,
#  '洗浄': 679,
#  '医薬': 680,
#  'チューインガム': 681,
#  'ベース': 682,
#  'スチレン・ブタジエンゴム': 683,
#  'ゴム': 684,
#  '重合': 685,
#  '乳化剤': 686,
#  '顔料': 687,
#  '表面': 688,
#  'コーティング': 689,
#  '添加': 690,
#  '脱色': 691,
#  'hydrogenated': 692,
#  '不': 693,
#  '均': 694,
#  'disproportionated': 695,
#  '物性': 696,
#  '適する': 697,
#  'よう': 698,
#  '各種': 699,
#  '誘導体': 700,
#  'なお': 701,
#  '際': 702,
#  '沸点': 703,
#  'バイオ': 704,
#  'マス': 705,
#  'り': 706,
#  'ゅうかちっそ': 707,
#  'nitrogen': 708,
#  '窒素': 709,
#  '無機': 710,
#  '組成': 711,
#  '数種類': 712,
#  '陽性': 713,
#  '陰性': 714,
#  '窒化': 715,
#  '明るい': 716,
#  '橙': 717,
#  '結晶': 718,
#  'サーモクロミズム': 719,
#  '示し': 720,
#  '−': 721,
#  '30': 722,
#  '赤色': 723,
#  '密度': 724,
#  '.': 725,
#  '22': 726,
#  '15': 727,
#  '℃)': 728,
#  '生成': 729,
#  '138': 730,
#  '8': 731,
#  'kcal': 732,
#  'mol': 733,
#  '単': 734,
#  '斜': 735,
#  '晶': 736,
#  '系': 737,
#  '空間': 738,
#  '群': 739,
#  'h': 740,
#  '双極': 741,
#  '子': 742,
#  'モーメント': 743,
#  ':\u3000': 744,
#  '72': 745,
#  'D': 746,
#  '溶液': 747,
#  '℃）': 748,
#  '反': 749,
#  '磁性': 750,
#  '磁化': 751,
#  '率': 752,
#  'χ': 753,
#  'M': 754,
#  '102': 755,
#  '×': 756,
#  '10': 757,
#  '6': 758,
#  'emu': 759,
#  '溶解': 760,
#  '度': 761,
#  '13': 762,
#  '19': 763,
#  'g': 764,
#  'L': 765,
#  '℃)、': 766,
#  '69': 767,
#  '05': 768,
#  '20': 769,
#  '018': 770,
#  '18': 771,
#  '中': 772,
#  'に対する': 773,
#  '近い': 774,
#  '1837': 775,
#  'スーベイラン': 776,
#  'Soubeiran': 777,
#  '二': 778,
#  '塩化': 779,
#  '通じる': 780,
#  'SCl': 781,
#  '＋': 782,
#  '16': 783,
#  'を通して': 784,
#  '生ずる': 785,
#  '平面': 786,
#  'なく': 787,
#  '舟': 788,
#  '型': 789,
#  '立体': 790,
#  '間': 791,
#  '結合': 792,
#  '距離': 793,
#  '62': 794,
#  'Å': 795,
#  '重': 796,
#  '中間': 797,
#  '長': 798,
#  '角': 799,
#  '°、': 800,
#  '105': 801,
#  '°': 802,
#  '起こす': 803,
#  '酸化': 804,
#  '128': 805,
#  '大変': 806,
#  '不安定': 807,
#  '加熱': 808,
#  '衝撃': 809,
#  '爆発': 810,
#  'アルカリ': 811,
#  '水溶液': 812,
#  '加水': 813,
#  '濃': 814,
#  '付加': 815,
#  '生じる': 816,
#  'チオ': 817,
#  'チアジル': 818,
#  '還元': 819,
#  '四': 820,
#  '形成': 821,
#  'ニトロ': 822,
#  'シル': 823,
#  '7': 824,
#  '紫': 825,
#  '外': 826,
#  '吸収': 827,
#  'スペクトル': 828,
#  '260': 829,
#  'nm': 830,
#  '極大': 831,
#  '塩': 832,
#  '混合': 833,
#  '雷管': 834,
#  '装填': 835,
#  '+=': 836,
#  '硫化': 837,
#  '真空': 838,
#  '300': 839,
#  'とともに': 840,
#  'オートクレーブ': 841,
#  '110': 842,
#  '長時間': 843,
#  '放置': 844,
#  'とも': 845,
#  '古': 846,
#  'ノルド': 847,
#  '北欧': 848,
#  '神話': 849,
#  '人物': 850,
#  '名前': 851,
#  '輝く': 852,
#  '彼': 853,
#  '豊穣': 854,
#  '神': 855,
#  'フレイ': 856,
#  '召使い': 857,
#  '幼なじみ': 858,
#  '後述': 859,
#  'ゲルズ': 860,
#  '貴方': 861,
#  '妖精': 862,
#  'アース': 863,
#  '賢い': 864,
#  'ヴァン': 865,
#  '尋ね': 866,
#  '否定': 867,
#  '属する': 868,
#  '種族': 869,
#  'はっきり': 870,
#  'おそらく': 871,
#  '人間': 872,
#  '『': 873,
#  'エッダ': 874,
#  '』': 875,
#  'ロキ': 876,
#  '口論': 877,
#  '序文': 878,
#  'において': 879,
#  '海神': 880,
#  'エーギル': 881,
#  '館': 882,
#  '開催': 883,
#  '酒宴': 884,
#  'みな': 885,
#  '招か': 886,
#  'ビュグヴィル': 887,
#  'ベイラ': 888,
#  '参加': 889,
#  'ものの': 890,
#  '松谷': 891,
#  '健二': 892,
#  '分身': 893,
#  '活躍': 894,
#  '歌': 895,
#  '物語': 896,
#  'にぎやか': 897,
#  '創作': 898,
#  'だ': 899,
#  '考え': 900,
#  'ラグナ': 901,
#  'ロク': 902,
#  '到来': 903,
#  '時': 904,
#  '運命': 905,
#  '語ら': 906,
#  '巨人': 907,
#  'ギュミル': 908,
#  '娘': 909,
#  '求婚': 910,
#  '使者': 911,
#  'ヨトゥンヘイム': 912,
#  '出向き': 913,
#  '褒美': 914,
#  '剣': 915,
#  '与え': 916,
#  '無く': 917,
#  '鹿': 918,
#  'スルト': 919,
#  '戦う': 920,
#  '経緯': 921,
#  'スノッリ': 922,
#  'ギュルヴィ': 923,
#  'たぶらかし': 924,
#  '37': 925,
#  '章': 926,
#  '同じ': 927,
#  '出来事': 928,
#  '危険': 929,
#  '旅': 930,
#  '馬': 931,
#  '貰い': 932,
#  'たい': 933,
#  '申し出': 934,
#  '快く': 935,
#  '承諾': 936,
#  '終わっ': 937,
#  '返し': 938,
#  'エピソード': 939,
#  '同様': 940,
#  '家': 941,
#  '囲む': 942,
#  '暗く': 943,
#  '揺らめく': 944,
#  '炎': 945,
#  '乗り越え': 946,
#  'スールル': 947,
#  'いわ': 948,
#  'ブローズグホーヴィ': 949,
#  '不明': 950,
#  'オーディン': 951,
#  '命じ': 952,
#  'スヴァルトアールヴヘイム': 953,
#  '狼': 954,
#  'フェンリル': 955,
#  '拘束': 956,
#  '魔法': 957,
#  '紐': 958,
#  'グレイプニル': 959,
#  '小人': 960,
#  '製作': 961,
#  'それ': 962,
#  'アースガルズ': 963,
#  '持ち帰っ': 964,
#  '34': 965,
#  '述べ': 966,
#  'イギリス': 967,
#  '著述': 968,
#  'ドナルド': 969,
#  'A': 970,
#  'マッケンジー': 971,
#  'による': 972,
#  'ロマン': 973,
#  'ゲル': 974,
#  '題': 975,
#  'ヘルモーズ': 976,
#  '役割': 977,
#  'かんげん': 978,
#  'とう': 979,
#  'reducing': 980,
#  'sugar': 981,
#  '塩基': 982,
#  '糖': 983,
#  '適当': 984,
#  'アルドン': 985,
#  'アル': 986,
#  'ダル': 987,
#  '与える': 988,
#  'ケトース': 989,
#  'および': 990,
#  '転化': 991,
#  '上白': 992,
#  '白': 993,
#  '液': 994,
#  ')）': 995,
#  '環状': 996,
#  'とる': 997,
#  '開': 998,
#  '環': 999,
#  ...}
